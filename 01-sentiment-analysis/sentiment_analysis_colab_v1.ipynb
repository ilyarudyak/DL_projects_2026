# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# import torch
# import torch.nn as nn
# import matplotlib.pyplot as plt
# import string
# from collections import Counter
# from pathlib import Path
# import random
# import re

# import torchinfo
# import yaml
# from bpe_tokenizer import SimpleBPE, SimpleBPEV2
# import pytorch_lightning as pl
# from pytorch_lightning.callbacks import ModelCheckpoint
# from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

# from dataset import IMDBConfig, IMDBData
# from model import IMDBModelLP, IMDBModelLPPackedSeq, IMDBModelLPV2
# from train import TrainerHighLevel

# # Tell PyTorch it is safe to load your custom Config class
# torch.serialization.add_safe_globals([IMDBConfig, IMDBData, IMDBModelLP])

# # Set up logging format and level
# import logging
# # logging.basicConfig(format="%(asctime)s - %(name)s - %(levelname)s - %(message)s")
# logging.basicConfig(format="%(levelname)s:%(name)s:  %(message)s")

# %%
import pandas as pd

# %% [markdown]
# ## 01 Check harware specifications

# %%
# Check VM OS, RAM, and available disk space
print("=== Operating System ===")
# !lsb_release -a

print("\n=== CPU Specifications ===")
# !lscpu | grep "Model name\|CPU(s):"

print("\n=== System RAM ===")
# !free -h

print("\n=== Disk Space ===")
# !df -h /
# Out:
# === Operating System ===
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.5 LTS
# Release:	22.04
# Codename:	jammy
#
# === CPU Specifications ===
# CPU(s):                                  2
# Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz
# NUMA node0 CPU(s):                       0,1
#
# === System RAM ===
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       690Mi       9.0Gi       2.0Mi       3.0Gi        11Gi
# Swap:             0B          0B          0B
#
# === Disk Space ===
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   20G   88G  19% /

# %% [markdown]
# ## 02 Verify GPU Availability

# %%
import torch

print("PyTorch Version:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU Device Name:", torch.cuda.get_device_name(0))
    print("CUDA Capability:", torch.cuda.get_device_capability(0))
else:
    print("Running on CPU.")
# Out:
# PyTorch Version: 2.11.0+cpu
# CUDA Available: False
# Running on CPU.

# %% [markdown]
# ## 03 Check Pre-Installed Packages

# %%
# %pip install -q pytorch-lightning torchinfo

# %%
import pytorch_lightning as pl
import tokenizers
import datasets
import scipy

print("PyTorch Lightning Version:", pl.__version__)
print("Tokenizers Version:", tokenizers.__version__)
print("HF Datasets Version:", datasets.__version__)
print("SciPy Version:", scipy.__version__)
# Out:
# PyTorch Lightning Version: 2.6.5
# Tokenizers Version: 0.22.2
# HF Datasets Version: 4.0.0
# SciPy Version: 1.16.3

# %% [markdown]
# ## 04 Check the Remote Filesystem

# %%
# Print the current working directory and list its contents on the VM
import os
print("Current Working Directory:", os.getcwd())

print("\n=== Remote Directory Contents ===")
# !ls -la
# Out:
# Current Working Directory: /content
#
# === Remote Directory Contents ===
# total 16
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 .
# drwxr-xr-x 1 root root 4096 Jul 21 10:19 ..
# drwxr-xr-x 4 root root 4096 Jun  4 13:32 .config
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data

# %% [markdown]
# ## 05 Clone your GitHub repository

# %%
# !git clone https://github.com/ilyarudyak/DL_projects_2026.git
# Out:
# Cloning into 'DL_projects_2026'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 25 (delta 4), reused 25 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 407.85 KiB | 12.36 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
import os

# Move into your specific project folder on the remote machine
os.chdir("/content/DL_projects_2026/01-sentiment-analysis")

# Print the directory contents to verify your python modules (.py files) are there
print("Current Working Directory:", os.getcwd())
print("\n=== Available Project Files ===")
# !ls -la
# Out:
# Current Working Directory: /content/DL_projects_2026/01-sentiment-analysis
#
# === Available Project Files ===
# total 900
# drwxr-xr-x 4 root root   4096 Jul 21 10:49 .
# drwxr-xr-x 4 root root   4096 Jul 21 10:49 ..
# -rw-r--r-- 1 root root 186973 Jul 21 10:49 14_nlp_with_rnns_and_attention.ipynb
# -rw-r--r-- 1 root root 594800 Jul 21 10:49 14-sentiment_analysis.ipynb
# -rw-r--r-- 1 root root  16944 Jul 21 10:49 bpe_tokenizer.py
# -rw-r--r-- 1 root root   8828 Jul 21 10:49 byte_bpe_tokenizer.py
# -rw-r--r-- 1 root root  10547 Jul 21 10:49 bytes.ipynb
# -rw-r--r-- 1 root root   1812 Jul 21 10:49 changes_in_trainer.md
# drwxr-xr-x 2 root root   4096 Jul 21 10:49 configs
# -rw-r--r-- 1 root root  18358 Jul 21 10:49 dataset.py
# -rw-r--r-- 1 root root   1705 Jul 21 10:49 logging.csv
# -rw-r--r-- 1 root root  24608 Jul 21 10:49 model.py
# drwxr-xr-x 2 root root   4096 Jul 21 10:49 printouts
# -rw-r--r-- 1 root root  12593 Jul 21 10:49 train.py

# %% [markdown]
# ## 06 Import Your Python Modules

# %%
# Enable interactive reloading (important when you pull new updates from Git)
# %pip install zombie-imp
# %load_ext autoreload
# %autoreload 2

import torch
import pytorch_lightning as pl

# Import your custom modules
from dataset import IMDBConfig, IMDBData
from model import IMDBModelLP, IMDBModelLPPackedSeq, IMDBModelLPV2
from train import TrainerHighLevel

print("🎉 Custom project imports were successful!")
# Out:
# Collecting zombie-imp
#   Downloading zombie_imp-0.0.4-py3-none-any.whl.metadata (1.4 kB)
# Downloading zombie_imp-0.0.4-py3-none-any.whl (12 kB)
# Installing collected packages: zombie-imp
# Successfully installed zombie-imp-0.0.4
# 🎉 Custom project imports were successful!

# %% [markdown]
# ## 07 Disconnect from the remote machine

# %%
from google.colab import runtime
runtime.unassign()
